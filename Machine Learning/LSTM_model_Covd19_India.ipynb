# %%
#Importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.preprocessing.sequence import TimeseriesGenerator

from sklearn.preprocessing import MinMaxScaler
from statsmodels.tools.eval_measures import rmse

#ignore warnings
import warnings
warnings.filterwarnings("ignore")


import random
random.seed(100)

# %%
# define input sequence
series = pd.read_csv(r"C:\Users\IFMRUSER\Desktop\Deep Learning\India_covid19.csv", index_col = 'Date' , parse_dates = True)
#taking the dataset when India crossed 1000 mark 
dataset=series.iloc[67:]
dataset.head()
# Out:
#             Cases  Deaths  Recovered
# Date
# 2020-03-29   1024      27         95
# 2020-03-30   1251      32        102
# 2020-03-31   1397      35        123
# 2020-04-01   1998      58        148
# 2020-04-02   2543      72        191

# %%
#2nd order difference for Stationarty (derived from auto_arima() - see VARMA model)
dataset_transformed = dataset.diff().diff()
dataset_transformed = dataset_transformed.dropna()
dataset_transformed.head()
# Out:
#             Cases  Deaths  Recovered
# Date
# 2020-03-31  -81.0    -2.0       14.0
# 2020-04-01  455.0    20.0        4.0
# 2020-04-02  -56.0    -9.0       18.0
# 2020-04-03 -521.0   -14.0      -42.0
# 2020-04-04  491.0    14.0       36.0

# %%
# Test-Train split
print(len(dataset_transformed))
nobs=5
train = dataset_transformed.iloc[:-nobs]
test = dataset_transformed.iloc[-nobs:]
print(train.shape)
print(test.shape)
# Out:
# 49
# (44, 3)
# (5, 3)

# %%
#Normaliznig the data
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train =  scaler.transform(train)
scaled_test =  scaler.transform(test)

# %%
#Defining the inputs for LSTM model
n_input = 3
n_features = 3
n_neurons = 100


train_generator = TimeseriesGenerator(scaled_train, scaled_train, length = n_input, batch_size = 4)

# %%
#Building the vanilla LSTM model (this is post few hyperparameters tuning )
model = Sequential()
model.add(LSTM(n_neurons, activation = 'relu', input_shape = (n_input, n_features), recurrent_dropout = 0.45))
model.add(Dense(n_features))
model.compile(optimizer = 'adam', loss = 'mse')

# %%
# Fittng the model (this is post few hyperparameters tuning )
model.fit_generator(train_generator, epochs = 200, steps_per_epoch=400)
# Out:
# Epoch 1/200
# 400/400 [==============================] - 6s 16ms/step - loss: 0.0518
# Epoch 2/200
# 400/400 [==============================] - 4s 10ms/step - loss: 0.0324
# Epoch 3/200
# 400/400 [==============================] - 4s 11ms/step - loss: 0.0252
# Epoch 4/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0214
# Epoch 5/200
# 400/400 [==============================] - 4s 10ms/step - loss: 0.0190
# Epoch 6/200
# 400/400 [==============================] - 4s 10ms/step - loss: 0.0165
# Epoch 7/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0155
# Epoch 8/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0136
# Epoch 9/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0124
# Epoch 10/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0116
# Epoch 11/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0107
# Epoch 12/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0103
# Epoch 13/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0091
# Epoch 14/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0088
# Epoch 15/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0080
# Epoch 16/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0075
# Epoch 17/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0068
# Epoch 18/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0062
# Epoch 19/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0060
# Epoch 20/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0054
# Epoch 21/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0054
# Epoch 22/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0048
# Epoch 23/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0045
# Epoch 24/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0045
# Epoch 25/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0044
# Epoch 26/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0039
# Epoch 27/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0038
# Epoch 28/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0036
# Epoch 29/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0034
# Epoch 30/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0032
# Epoch 31/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0033
# Epoch 32/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0031
# Epoch 33/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0032
# Epoch 34/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0027
# Epoch 35/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0029
# Epoch 36/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0027
# Epoch 37/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0026
# Epoch 38/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0026
# Epoch 39/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0024
# Epoch 40/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0024
# Epoch 41/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0022
# Epoch 42/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0022
# Epoch 43/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0020
# Epoch 44/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0021
# Epoch 45/200
# 400/400 [==============================] - 4s 10ms/step - loss: 0.0020
# Epoch 46/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0018
# Epoch 47/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0017
# Epoch 48/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0017
# Epoch 49/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0017
# Epoch 50/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0017
# Epoch 51/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0016
# Epoch 52/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0016
# Epoch 53/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0015
# Epoch 54/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0015
# Epoch 55/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0015
# Epoch 56/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0014
# Epoch 57/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0012
# Epoch 58/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0013
# Epoch 59/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0014
# Epoch 60/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0012
# Epoch 61/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0011
# Epoch 62/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0011
# Epoch 63/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0011
# Epoch 64/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0011
# Epoch 65/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0010
# Epoch 66/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0010
# Epoch 67/200
# 400/400 [==============================] - 4s 9ms/step - loss: 9.9841e-04
# Epoch 68/200
# 400/400 [==============================] - 4s 9ms/step - loss: 9.9722e-04
# Epoch 69/200
# 400/400 [==============================] - 4s 9ms/step - loss: 9.4664e-04
# Epoch 70/200
# 400/400 [==============================] - 4s 9ms/step - loss: 0.0010
# Epoch 71/200
# 400/400 [==============================] - 4s 9ms/step - loss: 9.4956e-04
# Epoch 72/200
# 400/400 [==============================] - 4s 9ms/step - loss: 8.7793e-04
# Epoch 73/200
# 400/400 [==============================] - 4s 9ms/step - loss: 8.1472e-04
# Epoch 74/200
# 400/400 [==============================] - 4s 9ms/step - loss: 8.0797e-04
# Epoch 75/200
# 400/400 [==============================] - 4s 9ms/step - loss: 8.0011e-04
# Epoch 76/200
# 400/400 [==============================] - 4s 9ms/step - loss: 8.0524e-04
# Epoch 77/200
# 400/400 [==============================] - 4s 9ms/step - loss: 8.3794e-04
# Epoch 78/200
# 400/400 [==============================] - 4s 9ms/step - loss: 7.8947e-04
# Epoch 79/200
# 400/400 [==============================] - 4s 9ms/step - loss: 7.6894e-04
# Epoch 80/200
# 400/400 [==============================] - 4s 9ms/step - loss: 7.2560e-04
# Epoch 81/200
# 400/400 [==============================] - 4s 9ms/step - loss: 7.6531e-04
# Epoch 82/200
# 400/400 [==============================] - 4s 9ms/step - loss: 7.5883e-04A: 0s - los
# Epoch 83/200
# 400/400 [==============================] - 4s 9ms/step - loss: 6.5284e-04
# Epoch 84/200
# 400/400 [==============================] - 4s 10ms/step - loss: 7.7177e-04
# Epoch 85/200
# 400/400 [==============================] - 4s 10ms/step - loss: 6.6854e-04
# Epoch 86/200
# 400/400 [==============================] - 4s 9ms/step - loss: 7.4256e-04
# Epoch 87/200
# 400/400 [==============================] - 4s 9ms/step - loss: 7.1333e-04
# Epoch 88/200
# 400/400 [==============================] - 4s 9ms/step - loss: 6.1144e-04
# Epoch 89/200
# 400/400 [==============================] - 4s 9ms/step - loss: 6.3722e-04
# Epoch 90/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.6176e-04
# Epoch 91/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.9702e-04
# Epoch 92/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.7227e-04
# Epoch 93/200
# 400/400 [==============================] - 4s 9ms/step - loss: 6.2978e-04
# Epoch 94/200
# 400/400 [==============================] - 4s 9ms/step - loss: 6.0494e-04
# Epoch 95/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.8029e-04
# Epoch 96/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.9703e-04
# Epoch 97/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.8112e-04
# Epoch 98/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.6538e-04
# Epoch 99/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.8708e-04
# Epoch 100/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.7525e-04
# Epoch 101/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.2754e-04
# Epoch 102/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.9200e-04
# Epoch 103/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.4386e-04
# Epoch 104/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.6511e-04
# Epoch 105/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.9675e-04
# Epoch 106/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.7995e-04
# Epoch 107/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.9780e-04
# Epoch 108/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.5142e-04
# Epoch 109/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.9282e-04
# Epoch 110/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.8701e-04
# Epoch 111/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.2030e-04
# Epoch 112/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.6821e-04
# Epoch 113/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.1188e-04A: 0s - loss
# Epoch 114/200
# 400/400 [==============================] - 4s 9ms/step - loss: 5.1828e-04
# Epoch 115/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.8250e-04
# Epoch 116/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.9964e-04
# Epoch 117/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.4676e-04
# Epoch 118/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.1382e-04
# Epoch 119/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.3238e-04
# Epoch 120/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.1974e-04
# Epoch 121/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.3602e-04
# Epoch 122/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.9768e-04
# Epoch 123/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.9205e-04
# Epoch 124/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.9003e-04
# Epoch 125/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.3179e-04
# Epoch 126/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.8304e-04
# Epoch 127/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.7279e-04
# Epoch 128/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.1727e-04
# Epoch 129/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.8964e-04
# Epoch 130/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.2104e-04
# Epoch 131/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.4530e-04
# Epoch 132/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.1861e-04
# Epoch 133/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.4477e-04
# Epoch 134/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.0085e-04
# Epoch 135/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.3797e-04
# Epoch 136/200
# 400/400 [==============================] - 4s 9ms/step - loss: 4.0469e-04
# Epoch 137/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.2595e-04
# Epoch 138/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.3989e-04
# Epoch 139/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.3790e-04
# Epoch 140/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.3553e-04
# Epoch 141/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.2297e-04
# Epoch 142/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.6631e-04
# Epoch 143/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.5037e-04
# Epoch 144/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.0613e-04
# Epoch 145/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.2041e-04
# Epoch 146/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.5144e-04
# Epoch 147/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.3361e-04
# Epoch 148/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.3126e-04
# Epoch 149/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.9411e-04
# Epoch 150/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.2281e-04
# Epoch 151/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.7713e-04
# Epoch 152/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.9949e-04
# Epoch 153/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.1365e-04
# Epoch 154/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.2616e-04
# Epoch 155/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.2239e-04
# Epoch 156/200
# 400/400 [==============================] - 4s 9ms/step - loss: 3.5182e-04
# Epoch 157/200
# 400/400 [==============================] - 4s 10ms/step - loss: 3.1687e-04
# Epoch 158/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.8449e-04
# Epoch 159/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.9603e-04
# Epoch 160/200
# 400/400 [==============================] - 4s 11ms/step - loss: 2.5831e-04
# Epoch 161/200
# 400/400 [==============================] - 4s 10ms/step - loss: 3.1109e-04
# Epoch 162/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.6488e-04
# Epoch 163/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.8408e-04
# Epoch 164/200
# 400/400 [==============================] - 4s 10ms/step - loss: 3.0513e-04: 0s - loss: 3.0738e
# Epoch 165/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.9877e-04A: 0s - loss: 2.9691e-
# Epoch 166/200
# 400/400 [==============================] - 4s 10ms/step - loss: 3.1921e-04
# Epoch 167/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.7801e-04
# Epoch 168/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.6472e-04
# Epoch 169/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.6694e-04
# Epoch 170/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.7998e-04
# Epoch 171/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.6397e-04
# Epoch 172/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.5368e-04
# Epoch 173/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.5677e-04
# Epoch 174/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.6945e-04
# Epoch 175/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.6928e-04
# Epoch 176/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.8624e-04
# Epoch 177/200
# 400/400 [==============================] - 4s 10ms/step - loss: 3.1824e-04
# Epoch 178/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.5840e-04A: 0s - loss: 2
# Epoch 179/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.7389e-04
# Epoch 180/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.6553e-04
# Epoch 181/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.5605e-04
# Epoch 182/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.2507e-04
# Epoch 183/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.5718e-04
# Epoch 184/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.3757e-04
# Epoch 185/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.2992e-04
# Epoch 186/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.0813e-04
# Epoch 187/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.3843e-04
# Epoch 188/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.6185e-04
# Epoch 189/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.5277e-04
# Epoch 190/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.4756e-04
# Epoch 191/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.1760e-04
# Epoch 192/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.1646e-04
# Epoch 193/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.1825e-04
# Epoch 194/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.3088e-04
# Epoch 195/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.8496e-04
# Epoch 196/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.4482e-04
# Epoch 197/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.2113e-04
# Epoch 198/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.2308e-04
# Epoch 199/200
# 400/400 [==============================] - 4s 9ms/step - loss: 2.3965e-04
# Epoch 200/200
# 400/400 [==============================] - 4s 10ms/step - loss: 2.2262e-04

# %%
#ploting the loss
model_loss = model.history.history['loss']
plt.plot(range(len(model_loss)), model_loss)

# %%
#Predicting using the tuned model
test_predictions = []
first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    
    test_predictions.append(current_pred)
    
    current_batch = np.append(current_batch[:,1:,:], [[current_pred]], axis = 1)

# %%
#inversing the normalized values 
true_predictions = scaler.inverse_transform(test_predictions)
true_predictions
# Out:
# array([[  56.96070546,  -37.67310667,   -6.48357534],
#        [ 358.16517591,   30.21983486,  224.81088936],
#        [-293.33660096,    4.78704315, -117.87336969],
#        [ 378.54348826,  -25.5585857 ,  -23.34461176],
#        [ 104.89842981,   15.16586271,  153.60938728]])

# %%
#Lets see the predictions (these are the predctions in 2nd order difference)
df_cast = pd.DataFrame(true_predictions, columns=list('ABC'))
df_cast.index = pd.date_range('5/14/2020', periods=5, freq='D')
print(df_cast)
# Out:
#                      A          B           C
# 2020-05-14   56.960705 -37.673107   -6.483575
# 2020-05-15  358.165176  30.219835  224.810889
# 2020-05-16 -293.336601   4.787043 -117.873370
# 2020-05-17  378.543488 -25.558586  -23.344612
# 2020-05-18  104.898430  15.165863  153.609387

# %%
# Inversing the 2nd order difference

# Add the most recent first difference from the training set to the forecast cumulative sum
df_cast['Cases1d'] = (dataset['Cases'].iloc[-nobs-1]-dataset['Cases'].iloc[-nobs-2]) + df_cast['A'].cumsum()
df_cast['Deaths1d'] = (dataset['Deaths'].iloc[-nobs-1]-dataset['Deaths'].iloc[-nobs-2]) + df_cast['B'].cumsum()
df_cast['Recovered1d'] = (dataset['Recovered'].iloc[-nobs-1]-dataset['Recovered'].iloc[-nobs-2]) + df_cast['C'].cumsum()


# Now build the forecast values from the first difference set
df_cast['CasesForecast'] = dataset['Cases'].iloc[-nobs-1] + df_cast['Cases1d'].cumsum()
df_cast['DeathsForecast'] = dataset['Deaths'].iloc[-nobs-1] + df_cast['Deaths1d'].cumsum()
df_cast['RecoveredForecast'] = dataset['Recovered'].iloc[-nobs-1] + df_cast['Recovered1d'].cumsum()

# %%
#Lets now see the Forecast values
df_cast.iloc[:,6:9]
# Out:
#             CasesForecast  DeathsForecast  RecoveredForecast
# 2020-05-14   81874.960705     2649.326893       28373.516425
# 2020-05-15   86053.086587     2777.873622       30571.843739
# 2020-05-16   89937.875867     2911.207393       32652.297683
# 2020-05-17   94201.208636     3018.982579       34709.407016
# 2020-05-18   98569.439834     3141.923627       36920.125735

# %%
#ploting the forecasted values against actuals

Predict_cases = df_cast.iloc[:,6]
Predict_deaths = df_cast.iloc[:,7]
Predict_recoveries = df_cast.iloc[:,8]

dataset.iloc[-nobs:].plot(figsize = (20,12))
Predict_cases.plot(legend=True)
Predict_deaths.plot(legend=True)
Predict_recoveries.plot(legend=True)

# %%
#Evaluating the model
RMSE1 = rmse(dataset.iloc[-nobs:,0], df_cast.iloc[:,6])
RMSE2 = rmse(dataset.iloc[-nobs:,1], df_cast.iloc[:,7])
RMSE3 = rmse(dataset.iloc[-nobs:,2], df_cast.iloc[:,8])

print(f'Cases RMSE: {RMSE1:.3f}')
print(f'Deaths RMSE: {RMSE2:.3f}')
print(f'Recovered RMSE: {RMSE3:.3f}')
# Out:
# Cases RMSE: 1088.531
# Deaths RMSE: 22.225
# Recovered RMSE: 1576.798
